# %% [markdown]
# # **Project Name**    - Play Store App Review Analysis

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis
# ##### **Contribution**    - Individual
# ##### **Name**            - Harivignesh M

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# In this Project I have two Datasets, one containing all the app details available in the Play Store, and the other containing user reviews and their sentiment.
#
# The objective of this project is to provide various insights for businesses to develop an app through a complete analysis of Play Store apps.
#
# I have Analyzed in various aspects such as,
#
# (i) Which type of app is mostly preferred by a user like Free or Paid ?
#
# (ii) In which Category a app should be developed
#
# (iii) Review counts over the time ,Top 10 Reviews according to the sentiment
#
# (iv) Correlation of the data
#
# Additionally, I have analyzed even more factors which will be useful for the development of businesses.
#
# According to my Analysis, I have determined that if the development process is properly structured and the app is designed to meet user expectations, it will be highly welcomed by users.
#
# Otherwise, the development team should remain focused after the release of an app and should actively seek feedback and use it to further develop the app.
#
# So, when come to the point of improvement in a app,we should focus on three sections such as number of Installs,sentiment of the Reviews,range of Ratings
# These three plays a major role in which a app will be determined by the user.
#
# Focus your attention on the development process and strive to achieve the desired outcome. Doing so will ensure that you are successful in your endeavors.
#
# See the analysis, gain insights and develop accordingly. Utilize the analysis to gain a better understanding of the situation and make informed decisions that will lead to successful outcomes.By leveraging data-driven insights, you can create an app that meets the needs of your customers and helps your business reach its goals. With the right app, you can unlock new opportunities for growth and success.
#
# Let's dive into the project and uncover all its objectives and insights.
#
#
# ---

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# To thoroughly analyze the data of apps in the Play Store and provide positive outcomes for business growth, as well as to identify and prevent apps that are in decline.
#
# To investigate and analyze the data to uncover the essential elements that contribute to an app's engagement.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Gain insights to develop an app that will drive positive growth for your business.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sea
# !pip install squarify
import squarify
import missingno as msno
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

# Assigning the path to the Dataset 1
path = '/content/drive/My Drive/PROJECTS/Capstone Project - Play store/'
df = pd.read_csv(path + 'Play Store Data.csv')

# Assigning the path to the Dataset 2
path = '/content/drive/My Drive/PROJECTS/Capstone Project - Play store/'
df2 = pd.read_csv(path + 'User Reviews.csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset 1 First Look
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Dataset 2 First Look
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset 1 - Rows & Columns count
df.shape
# Out:
# (10841, 13)

# %%
# Dataset 2 - Rows & Columns count
df2.shape
# Out:
# (64295, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset 1 - Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Dataset 2 - Info
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dropping the Duplicates in our Dataset
# Before Dropping Duplicates our Dataset contains 10841 rows × 13 columns

dfall = df.drop_duplicates('App')
# After Dropping Duplicates our Dataset contains  9660 rows × 13 columns

# Total view of our Dataset after dropng Duplicates
print(dfall.shape)
dfall.head()
# Out:
# (9660, 13)
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count for Dataset 1
dfall.isna().sum().sum()
# Out:
# 1476

# %%
# Missing Values/Null Values Count for Dataset 2
df2.isna().sum().sum()
# Out:
# 107457

# %%
# Visualizing the missing values
msno.bar(dfall)

# %%
# Visualizing the missing values
msno.bar(df2)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# I have two datasets related to Playstore apps.
#
# The first dataset contains 10841 rows and 13 columns, which include details such as name, category, size, and rating. After removing duplicates, the dataset is reduced to 9660 rows and 13 columns.
#
# The second dataset contains 64295 rows and 5 columns, which include details such as name, review, and sentiment.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset 1 - Columns
dfall.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset 2 - Columns
df2.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset 1 - Describe
dfall.describe(include='all')
# Out:
#                                                    App Category       Rating  \
# count                                             9660     9660  8197.000000
# unique                                            9660       34          NaN
# top     Photo Editor & Candy Camera & Grid & ScrapBook   FAMILY          NaN
# freq                                                 1     1832          NaN
# mean                                               NaN      NaN     4.175052
# std                                                NaN      NaN     0.561026
# min                                                NaN      NaN     1.000000
# 25%                                                NaN      NaN     4.000000
# 50%                                                NaN      NaN     4.300000
# 75%                                                NaN      NaN     4.500000
# max                                                NaN      NaN    19.000000
#
# ...

# %%
# Dataset 2 - Describe
df2.describe(include='all')
# Out:
#                         App Translated_Review Sentiment  Sentiment_Polarity  \
# count                 64295             37427     37432        37432.000000
# unique                 1074             27994         3                 NaN
# top     Angry Birds Classic              Good  Positive                 NaN
# freq                    320               247     23998                 NaN
# mean                    NaN               NaN       NaN            0.182146
# std                     NaN               NaN       NaN            0.351301
# min                     NaN               NaN       NaN           -1.000000
# 25%                     NaN               NaN       NaN            0.000000
# 50%                     NaN               NaN       NaN            0.150000
# 75%                     NaN               NaN       NaN            0.400000
# max                     NaN               NaN       NaN            1.000000
#
#         Sentiment_Subjectivity
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Dataset** **1**
#
# **App**	: Name of the Apps that avaiable in Play store
#
# **Category** : Category of that particular App (Ex : Game,Dating)
#
# **Rating** : Rating of that particular App
#
# **Reviews** : Number of Reviews of that particular App
#
# **Size**	: Size of that particular App
#
# **Installs** : Number of Installs for that particular App
#
# **Type** : This column denotes whether the App is Free or Paid
#
# **Price** : Price of the App
#
# **Content Rating** : This column denotes the content certification(Ex :Teen, Everyone)
#
# **Genres** : Sub-Category of Category section
#
# **Last** **Updated** : Last updated date of App
#
# **Current** **Version**	: Current version of the App
#
# **Android** **Version** : Android version which supports the App

# %% [markdown]
# **Dataset 2**
#
# **App**	: Name of the Apps that avaiable in Play store
#
# **Review**	: Reviews of that particular App
#
# **Sentiment**	: Sentimental Category of the Review (Ex: Positive,Negative,Neutral)
#
# **Sentiment_Polarity** : Gives the expression rating of the Sentiment, Ranges(-1,1)
#
# **Sentiment_Subjectivity** : Gives the amount of personal opinion in the Sentiment , Ranges(0,1)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Number of Unique values in each column in Dataset 1
for i in dfall.columns.tolist():
  print("No. of unique values in ",i,"is",dfall[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 34 .
# No. of unique values in  Rating is 40 .
# No. of unique values in  Reviews is 5331 .
# No. of unique values in  Size is 462 .
# No. of unique values in  Installs is 22 .
# No. of unique values in  Type is 3 .
# No. of unique values in  Price is 93 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 119 .
# No. of unique values in  Last Updated is 1378 .
# No. of unique values in  Current Ver is 2818 .
# No. of unique values in  Android Ver is 33 .

# %%
# Number of Unique values in each column in Dataset 2
for i in df2.columns.tolist():
  print("No. of unique values in ",i,"is",df2[i].nunique(),".")
# Out:
# No. of unique values in  App is 1074 .
# No. of unique values in  Translated_Review is 27994 .
# No. of unique values in  Sentiment is 3 .
# No. of unique values in  Sentiment_Polarity is 5410 .
# No. of unique values in  Sentiment_Subjectivity is 4474 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
#  **Objective 1 : To analyze whether Arts and Design apps have better rating than others**

# %%
# Grouping Category and Rating columns with count function, also dropping ['1.9' in Category,'19.0' in Rating] values in this which is invalid.
playstore_app = dfall.groupby(['Category','Rating'])['Rating'].count().unstack().drop([19.0], axis = 1).drop(['1.9'], axis = 0)

# Separating the Rating above 4.0 which will be considered as the best
separated_data = playstore_app.iloc[:,-10:]

# Taking Number of Rating above 4.0 using Sum method
df1 = separated_data.sum(axis = 1)
# Changing the above column into a Series
series1 = pd.Series(df1)

# Taking the Total number of Rating for each Category
total_rating = playstore_app.sum(axis = 1)
# Changing the above column into a Series
series2 = pd.Series(total_rating)

# Making an Average for each Category to see which Tops the board
Average_rating = ((df1 / total_rating)*100).round()
# Changing the above column into a Series
series3 = pd.Series(Average_rating)

# Concating Three datas to get a better look 
Apps_total_rating = pd.concat([series1,series2,series3], axis = 1)
# Renaming the columns
Apps_total_rating.rename(columns = {0:'Ratings > 4.0',1:'Total Ratings',2:'Average Rating'}, inplace = True)

# %% [markdown]
#  **Objective 2: To analyze whether Free apps have more installs than paid apps**

# %%
# Grouping Installs and Type columns, also dropping ['Free' in Installs ,'0' in Type] values in this which is invalid.
installs = dfall.groupby(['Installs','Type'])['Type'].count().unstack().drop(['0'],axis = 1).drop(['Free'],axis = 0)
installs_ = installs.fillna('0',inplace = True)

# Separating the Free apps with Installs column
installed_free =  dfall.loc[df['Type'] == 'Free'].loc[:,'Installs']
# Replacing the special characters and changing the type of column - Installs
installed_free_app =installed_free.replace('\W','',regex=True).astype(float)
# Taking the mean value for comparison
x = installed_free_app.mean()

# Separating the Paid apps with Installs column
installed_paid =  dfall.loc[df['Type'] == 'Paid'].loc[:,'Installs']
## Replacing the special characters and changing the type of column - Installs
installed_paid_app =installed_paid.replace('\W','',regex=True).astype(float)
# Taking the mean value for comparison
y = installed_paid_app.mean()

# Assigning the results 
types_of_apps = ['Free','Paid']
average_of_apps = [ x,y]

# %% [markdown]
# **Objective 3: To analyze Review counts over the Time**

# %%
# Every column in this app has been mismatched, so it has been removed from the dataset
droping_ = dfall.drop([10472])

# Changing the Review column type to int
droping_.Reviews = droping_.Reviews.astype(int)

# Grouping Category and Reviews columns, taking the Mean values,rounding the values and also sorting it.  
review_counts = droping_.groupby('Category')['Reviews'].mean().round().sort_values()

# %% [markdown]
# **Objective 4 : Analysis of sports category to see the Top 10 highest number of installed apps**

# %%
# Separating the Category - Sports, from that taking only column App and Installs.
# Replacing the special characters
Sports_ =  dfall.loc[df['Category'] == 'SPORTS'].loc[:,['App','Installs']].replace('\W','',regex=True)

# Changing the type of column - Installs
Sports_.Installs = Sports_.Installs.astype('float')

# Sorting the top 10 Apps using 'nlargest' method
Sports__ = Sports_.nlargest(n= 10, columns = 'Installs')

# %% [markdown]
# **Objective 5 : To Analyze which genre of Game category Installed the most**

# %%
# Separating the Category - Game, from that taking only columns App, Genres and Installs.
# Replacing the special characters
games_ = dfall.loc[dfall['Category']=='GAME'].loc[:,['App','Genres','Installs']].replace('\W','',regex=True)

# To show the value count with the visual
# Finding the value counts in each genre
games__= games_['Genres'].value_counts()

# Changing the type of column - Installs
games_.Installs = games_.Installs.astype('float')

# Finding the Sum of number of Installs in each Genre of Game Category and made a round value
games_high = games_.groupby('Genres')['Installs'].sum().round().sort_values()

# %% [markdown]
# **Objective 6: Analysis of sentiment of reviews given by users by Top 10 in each section of sentiments**

# %%
# Grouping the App and Sentiment columns from Dataset 2 
Review_counts = df2.groupby(['App','Sentiment'])['Sentiment'].count().unstack()

# %% [markdown]
# **(a) Top 10 Apps which got the Highest number of Positive Reviews**

# %%
# Getting top 10 Highest number of Postive reviews using 'nlargest' method.
Highest_positive_review= Review_counts['Positive'].nlargest(n=10)
# Changing the above column into a Dataframe
Highest_positive_review_ = pd.DataFrame(Highest_positive_review)

# %% [markdown]
# **(b) Top 10 Apps which got the Higher number of Negative Reviews**

# %%
# Getting top 10 Highest number of Negative reviews using 'nlargest' method.
Highest_negative_review= Review_counts['Negative'].nlargest(n=10)
# Changing the above column into a Dataframe
Highest_negative_review_ = pd.DataFrame(Highest_negative_review)

# %% [markdown]
# **(c) Top 10 Apps which got the Higher number of Neutral Reviews**

# %%
# Getting top 10 Highest number of Neutral reviews using 'nlargest' method.
Highest_neutral_review= Review_counts['Neutral'].nlargest(n=10)
# Changing the above column into a Dataframe
Highest_neutral_review_ = pd.DataFrame(Highest_neutral_review)

# %% [markdown]
# **Objective 7 : Analysis of top 10 Entertaining App ,with three different categories by the user**

# %%
# Separating the Category - Entertainment, from that taking columns App, Rating , Reviews and Installs.
# Replacing the special characters and setting App as the index.
df7 = dfall.loc[dfall['Category']=='ENTERTAINMENT'].loc[:,['App','Rating','Installs','Reviews']].replace('\W','',regex = True).set_index('App')

# Changing the type of columns Installs and Reviews 
df7.Installs = df7.Installs.astype(int)
df7.Reviews = df7.Reviews.astype(int)

# %%
# Getting top 10 Highest number of Installed App using 'nlargest' method.
df7_1= df7.nlargest(n = 10 , columns = 'Installs')

# %%
# Getting top 10 Highest App in Rating using 'nlargest' method.
df7_2= df7.nlargest(n = 10 , columns = 'Rating')

# %%
# Getting top 10 Highest number of Reviews that a App got using 'nlargest' method.
df7_3= df7.nlargest(n = 10 , columns = 'Reviews')

# %% [markdown]
# **Objective 8:To Analyze which app size has the Highest number of installs**

# %%
# Separating the Category - Game, from that taking columns Size and Installs.
''' Replacing the cells that have 
                    (a) 'Varies with device' with '0' in Size column
                    (b) Special characters 
                    (c) Size column also contains M denoting MB of the app,so making that as a space
                    (d) Size column also contains k denoting KB of the app,so making that as a '0' to differentiate from other apps
                    and resetting the index.'''

df8 = (dfall.loc[dfall['Category'] == 'GAME'].loc[:,['Size','Installs']].replace('Varies with device','0').replace('\W','',regex = True)
                     .replace('M','',regex = True).replace('k','0',regex = True).reset_index(drop = True))

# Changing the type of columns Installs and Size 
df8.Size = df8.Size.astype(int)
df8.Installs = df8.Installs.astype(int)

# Segregating the Apps according to the Size and also using Sum method to know the sum of number of Installs
df8_1 = df8.loc[(df8['Size'] >= 1 ) & (df8['Size']<=25)].sum()

df8_2= df8.loc[(df8['Size']>25) & (df8['Size'] < 50)].sum()

df8_3= df8.loc[(df8['Size']>=50) & (df8['Size'] < 100)].sum()

df8_4 = df8.loc[df8['Size']>=100].sum()

# The 'Varies with device' was replaced with 0, so taking that apps into consideration
df8_5 = df8.loc[df8['Size'] == 0].sum()

# Apps which are in KB size has been added with 0 at the end,so those values are above 1000.Taking that into consideration
df8_6 = df8.loc[df8['Size']>=1000].sum()

# Assigning Labels for each row
Categories = ['Below 25MB','25MB to 50MB','50MB to 100MB','Above 100MB','Varies with device','Apps in KB']

# Making the values as a Dataframe to align it 
df8_all = pd.DataFrame([df8_1,df8_2,df8_3,df8_4,df8_5,df8_6],index = Categories)

# We need Installs column alone,so separating that with labels 
df8_all_ = df8_all.loc[:,['Installs']]

# %% [markdown]
# **Objective 9 : Analysis of apps which got the highest Number of Reviews**

# %%
# Separating the columns App and Reviews,dropping the row '10472' which is not aligned properly and setting App as index
df9 = dfall.loc[:,['App','Reviews']].drop([10472]).set_index('App')

# Changing the type of Column into integer
df9.Reviews = df9.Reviews.astype(int)

# Getting top 10 Highest number of Reviews that a App got using 'nlargest' method.
df9_ = df9.nlargest(n=10, columns = 'Reviews')

# %% [markdown]
# **Objective 10 : Analysis of Medical category, to know the user preferences**

# %%
# Separating the Category - Medical, from that taking columns App and Installs
# Replacing the special characters
df10 = dfall.loc[dfall['Category'] == 'MEDICAL'].loc[:,['App','Installs']].replace('\W','',regex = True)

# Changing the type of Column into integer
df10.Installs = df10.Installs.astype(int)

# Getting top 10 Highest number of Installs that a App got using 'nlargest' method
# Replacing App name with short name for better visual
df10_ = (df10.nlargest(n=10 , columns = 'Installs')
           .replace('OviaPregnancyTrackerBabyCountdownCalendar','OviaPregnancyTracker',regex = True)
           .replace('OviaFertilityTrackerOvulationCalculator','OviaFertilityTracker',regex = True))

# %% [markdown]
# **Objectice 11: Analysis of Distribution of Rating**

# %%
# Separating columns Category and Rating. Setting Category as index
df11 = dfall.loc[:,['Category','Rating']].set_index('Category')

# Segregating the Apps according to the Rating and also using Count method to know the total count in each section
df11_1 = df11.loc[(df11['Rating'] >= 1.0) & (df11['Rating']< 2.0)].count()

df11_2 = df11.loc[(df11['Rating'] >= 2.0) & (df11['Rating']< 3.0)].count()                   
                   
df11_3 = df11.loc[(df11['Rating'] >= 3.0) & (df11['Rating']< 4.0)].count()

df11_4 = df11.loc[(df11['Rating'] >= 4.0) & (df11['Rating']<= 5.0)].count()

# Printing each value that we extracted
print(df11_1)
print(df11_2)
print(df11_3)
print(df11_4)
# Out:
# Rating    54
# dtype: int64
# Rating    225
# dtype: int64
# Rating    1631
# dtype: int64
# Rating    6286
# dtype: int64

# %%
# Assignng the values and labels to the variables for ease of Visualing
Rating_count = [54, 225, 1631, 6286 ]
Categories = ['1.0 to 2.0','2.0 to 3.0','3.0 to 4.0','4.0 to 5.0']

# %% [markdown]
# **Objective 12: Analysis of Highest Installs as per Category**

# %%
# Grouping columns Category and Installs.Dropping (1.9 row in Category) which is invalid
dfall.groupby('Category')['Installs'].count().drop(['1.9']).sort_values(ascending = False)

# Separating columns Category and Installs.Replacing the special characters
df12 = dfall.loc[:,['Category','Installs']].replace('\W','',regex = True).drop([10472])

# Changing the type of column Installs into integer
df12.Installs = df12.Installs.astype(int)

# Grouping columns Category and Installs.Taking Mean value for the column Installs 
df12_ = df12.groupby('Category')['Installs'].mean().round()

# %% [markdown]
# **Objective 13 : Correlation Heatmap for:**
#
# **(i) Categories - Arts and design,Family,Health and fitness.**
#
# **(ii) With complete data of Installs,Rating,Reviews,Size.**

# %%
# Grouping columns Category and Installs.Dropping (1.9 row in Category) which is invalid
dfall.groupby('Category')['Installs'].count().drop(['1.9']).sort_values(ascending = False)

# Separating the columns Rating,Reviews,Size and Installs.
df13_ = dfall.loc[:,['Rating','Reviews','Size','Installs']].replace(r'\D','0',regex = True)

# Changing the column Reviews,Size,Installs type into float
df13_.Reviews = df13_.Reviews.astype(float)
df13_.Size = df13_.Size.astype(float)
df13_.Installs = df13_.Installs.astype(float)

# Separating Category to merge with our existing Data
df13__ = dfall.loc[:,'Category']

# Merging both separated data into one
df13_1 = pd.merge(df13_, df13__, left_index=True, right_index=True)

# %% [markdown]
# **Objective 14: Pairplot**
#
# **Pairplot with columns - Installs,Rating,Reviews,Size in the aspect of  "Type"**

# %%
# Separating the columns Rating,Reviews,Size and Installs
df14_ = dfall.loc[:,['Rating','Reviews','Size','Installs']].replace(r'\D','0',regex = True)

# Changing the column Reviews,Size,Installs type into float
df14_.Reviews = df14_.Reviews.astype(float)
df14_.Size = df14_.Size.astype(float)
df14_.Installs = df14_.Installs.astype(float)

# Separating Category to merge with our existing Data
df14__ = dfall.loc[:,'Type']

# Merging both separated data into one
df14_1 = pd.merge(df14_, df14__, left_index=True, right_index=True)

# %% [markdown]
# **Objective 15 : Analysis of category - Dating by sorting the top 10 Highest number of Installs and within that analysing the top 10 apps with Highest Rating**

# %%
# Separating the Category - Dating, from that taking columns Rating and Installs
# Replacing the characters
df15 = dfall.loc[dfall['Category'] == 'DATING'].loc[:,['Rating','Installs']].replace('\D','',regex = True)

# Changing the column Installs into integer 
df15.Installs = df15.Installs.astype(int)

# Now separating column App to have a name of our apps
df15_ = dfall.loc[dfall['Category'] == 'DATING'].loc[:,['App']]

# Merging both data to have a clear view
df15_1 = pd.merge(df15_,df15,left_index = True , right_index = True).set_index('App')

# First taking the top 10 Highest number of Installed app  
df15_2 = df15_1.nlargest(n=10, columns = 'Installs')

# From the top 10 of Highest installs.sorting the top 10 App which got the highest Rating
df15_3 = df15_2.nlargest(n = 10, columns = 'Rating')

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# According to my analysis, we can gain insights into various categories and develop an app by referencing it. I have analyzed the main sections such as Installs, Size, Reviews, and Ratings, which will give us a clear indication of user expectations.
#
# In addition, I have conducted a thorough analysis of certain categories with specific conditions to provide a more comprehensive understanding of the category.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### **Chart - 1 -** **Objective 1 : To analyze whether Arts and Design apps have better rating than others**

# %%
# Chart - 1.1 visualization code

# Printing the Table to have a clear idea
print(Apps_total_rating)

# Showing the Visual using Stacked Bar chart  
Apps_total_rating.plot.barh(figsize = (10,10),fontsize = 12,stacked = True,color = ['red','gold','green'])

# Giving other labels
plt.title('Comparison of Ratings',fontsize = 18)
plt.xlabel('Ratings > 4.0 - Total Ratings - Average Rating',fontsize = 12)
plt.ylabel('Categories',fontsize = 12)
# Out:
#                      Ratings > 4.0  Total Ratings  Average Rating
# Category
# ART_AND_DESIGN                51.0           61.0            84.0
# AUTO_AND_VEHICLES             46.0           73.0            63.0
# BEAUTY                        30.0           42.0            71.0
# BOOKS_AND_REFERENCE          136.0          169.0            80.0
# BUSINESS                     171.0          263.0            65.0
# COMICS                        37.0           54.0            69.0
# COMMUNICATION                173.0          256.0            68.0
# DATING                        73.0          134.0            54.0
# EDUCATION                    102.0          118.0            86.0
# ENTERTAINMENT                 68.0          102.0            67.0
# EVENTS                        37.0           45.0            82.0
# FAMILY                      1110.0         1608.0            69.0
# FINANCE                      204.0          302.0            68.0
# ...

# %%
# Chart - 1.2 visualization code

# Printing the Table to have a clear idea
Average_rating_ = Average_rating.sort_values(ascending = False)
print(Average_rating_)

# Showing the Visual using Bar chart 
Average_rating.sort_values().plot.barh(figsize = (10,10),fontsize = 12, color = ['darkviolet'])

# Giving other labels
plt.title('Comparison of Ratings',fontsize = 18)
plt.xlabel('Average Rating above 4.0',fontsize = 12)
plt.ylabel('Apps',fontsize = 12)
# Out:
# Category
# PERSONALIZATION        87.0
# EDUCATION              86.0
# ART_AND_DESIGN         84.0
# EVENTS                 82.0
# BOOKS_AND_REFERENCE    80.0
# GAME                   78.0
# SOCIAL                 77.0
# SHOPPING               77.0
# PARENTING              76.0
# HEALTH_AND_FITNESS     76.0
# PRODUCTIVITY           74.0
# WEATHER                74.0
# SPORTS                 73.0
# BEAUTY                 71.0
# FOOD_AND_DRINK         71.0
# PHOTOGRAPHY            71.0
# COMICS                 69.0
# FAMILY                 69.0
# FINANCE                68.0
# MEDICAL                68.0
# COMMUNICATION          68.0
# ENTERTAINMENT          67.0
# LIBRARIES_AND_DEMO     67.0
# BUSINESS               65.0
# TRAVEL_AND_LOCAL       65.0
# NEWS_AND_MAGAZINES     64.0
# MAPS_AND_NAVIGATION    64.0
# AUTO_AND_VEHICLES      63.0
# TOOLS                  63.0
# VIDEO_PLAYERS          61.0
# HOUSE_AND_HOME         61.0
# LIFESTYLE              61.0
# ...

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# A bar chart is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another. By leveraging the power of bar charts, we can gain valuable insights into our data and make informed decisions.
#
# I chose a stacked horizontal bar chart for the first chart because it provides a comprehensive overview of the ratings by displaying all three columns in a single chart. For the second chart, I chose a horizontal bar chart, which clearly illustrates the order of the data.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Rating is incredibly important for an app, as it provides a direct view of our user base. According to the chart, the highest average rating of an app is 87% in the Personalization category, while the lowest average rating of an app is 54% in the Dating category.
#
# Contrary to our expectations, the Arts and Design category does not have the highest rating, and instead stands in third place.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
#
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# Most of the categories lie within the range of 60%-80% in terms of average ratings, which should be improved to have a greater business impact. A rating above 85% would be ideal. Categories with ratings lower than 60% will lead to negative growth, so they should be improved further.
#
# ---

# %% [markdown]
# #### **Chart - 2 - Objective 2: To analyze whether Free apps have more installs than paid apps**

# %%
# Chart - 2 visualization code

# Printing the values 
print(types_of_apps)
print(average_of_apps)

# Showing the Visual using Pie chart 
plt.figure(figsize=(8,8))
plt.pie(average_of_apps, labels= types_of_apps,explode = (0,0.5), startangle=90, autopct='%1.0f%%', 
        textprops={'fontsize': 16},colors = ['silver','tomato'])
plt.text(x=0, y=1.8, s='Percentage of Installed - Free vs Paid', fontsize=25)
# Out:
# ['Free', 'Paid']
# [8432439.075039318, 75879.47222222222]
# Text(0, 1.8, 'Percentage of Installed - Free vs Paid')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is an effective way to illustrate the part-to-whole relationship in a data. It is easy to explain the percentage comparison through the area covered in a circle, which is divided into different colors. Pie charts are frequently used when comparing different percentages. I used a pie chart to compare the percentage of the dependent variable, which proved to be a useful tool.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that 8,432,439 free apps were installed by users, representing 99% of all app installations, while 75879 paid apps were installed, representing 1%.
#
# This indicates that users have a clear preference for free apps.
#
# Users will also install paid apps if they truly appreciate the product based on reviews, ratings, and other factors, as 75879 users have already done so.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight will have a positive impact and provide direct facts on how the type of app should be designed to impress a large number of users. By leveraging this data, developers can create an app that is tailored to the needs of their target audience, ensuring that it stands out from the competition and provides a superior user experience.

# %% [markdown]
# #### **Chart - 3 - Objective 3: To analyze Review counts over the Time**

# %%
# Chart - 3 visualization code

# Showing the Visual using Bar chart 
review_counts.plot.barh( figsize =(10,10),fontsize = 12, color = ['crimson'])

# Giving other labels
plt.title('Review counts over the Time',fontsize = 18)
plt.xlabel('Average of Reviews',fontsize = 15)
plt.ylabel('Categories',fontsize = 15)
# Out:
# Text(0, 0.5, 'Categories')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another. By leveraging the power of bar charts, we can gain valuable insights into our data and make informed decisions.
#
# I chose a horizontal bar chart, which clearly illustrates the order of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The higher the number of reviews, the higher the user activity towards a particular app category. This indicates that the Social category has the highest active users, with the highest number of reviews at 953673, and the lowest number of reviews at 2516 by Event Category apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights found will undoubtedly help to foster positive business growth. The categories Social, Communication, and Gaming have the highest number of reviews over time, which indicates that there are a large number of active users. If the development part is improved, business will grow even more. The categories Event, Medical, and Beauty have fewer reviews, so they should focus on adopting new techniques or features to attract more users.

# %% [markdown]
# #### **Chart - 4 - Objective 4 : Analysis of sports category to see the Top 10 highest number of installed apps**

# %%
# Chart - 4 visualization code

# Showing the Visual using Treemap
plt.figure(figsize=(12,8), dpi= 80)

# Giving the requirements to make a visual in Treemap
squarify.plot(sizes= Sports__ ['Installs'], label= Sports__ ['App'],
              color=["dimgray","darkgrey","silver","lightgrey","whitesmoke","skyblue","lightcyan","deepskyblue","darkturquoise", "cyan"], alpha=.8 )

plt.axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Treemap is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another.
#
# I selected a Treemap to gain a clear visual representation of the data based on its size. This intuitive approach allows for a more comprehensive understanding of the information.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I have analyzed the sports category by highest number of installs, and 3D bowling and FIFA Soccer games are at the top of the list. This tells us about the mentality of the user, where the expectation is for a realistic gaming experience. It appears that users are more interested in animated games that they are used to playing or watching on a daily basis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight will help to create positive growth. We can take a reference to the app that topped the list and implement even more features in the developing app. Whatever game you are developing, make sure you understand the user's mentality and expectations. By doing so, you can ensure that your game meets the needs of your users and provides them with an enjoyable experience.

# %% [markdown]
# #### **Chart - 5 - Objective 5 : To Analyze which genre of Game category Installed the mostt**

# %%
# Chart - 5 visualization code

# printing the value counts of each genre to compare with the visual
print(games__)

# Showing the Visual using Bar chart
games_high.plot.barh( figsize =(10,10),fontsize = 12, color = ['sandybrown'])

# Giving other labels
plt.title('Highest Number of Installs in Category - Game',fontsize = 18)
plt.xlabel('Number of Installs',fontsize = 15)
plt.ylabel('Genre',fontsize = 15)
# Out:
# Action                       299
# Arcade                       184
# Racing                        91
# Adventure                     73
# Card                          47
# Board                         41
# Casino                        39
# Trivia                        38
# Puzzle                        24
# Casual                        23
# Word                          23
# Music                         19
# Strategy                      17
# RolePlaying                   15
# Simulation                    10
# Sports                         6
# ActionActionAdventure          3
# CasualBrainGames               1
# SimulationActionAdventure      1
# AdventureActionAdventure       1
# SimulationEducation            1
# CasualActionAdventure          1
# CasualPretendPlay              1
# CasualCreativity               1
# Name: Genres, dtype: int64
# Text(0, 0.5, 'Genre')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another. By leveraging the power of bar charts, we can gain valuable insights into our data and make informed decisions.
#
# I chose a horizontal bar chart, which clearly illustrates the order of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I analyzed the game category by highest number of installs by genre, and an interesting fact emerged: The number of apps in a genre does not necessarily affect the number of installs.
#
# For example, the Arcade genre has 184 apps, yet it tops the list in terms of app installations. Meanwhile, the Action genre has 299 apps, yet it comes in second place. Similarly, the Casual genre has only 23 apps, yet it surpasses the Racing genre, which has 91 apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights will help create a positive business impact, allowing us to understand that the genre of your app is not as important as its feasibility and ability to connect with the user.
# In some cases, the challenging levels of games are also more widely used by users. These levels provide an engaging and stimulating experience, allowing users to test their skills and push their boundaries. As a result, users are able to hone their gaming abilities and become more adept at problem-solving.

# %% [markdown]
# #### **Chart - 6 - Objective 6: Analysis of sentiment of reviews given by users by Top 10 in each section of sentiments**

# %%
# Chart - 6.1 visualization code

# Showing the Visual using Bar chart
Highest_positive_review.plot.barh(figsize = (10,10),fontsize = 12, color =['peachpuff','lightsalmon' ], edgecolor = 'black')

# Using for function to show the datalabels in Visual
for index,value in enumerate(Highest_positive_review_['Positive']):
    plt.text(value, index,str(value),fontsize = 12,ha = 'right', Bbox = dict(facecolor = 'orangered', alpha =.6))

# Giving other labels   
plt.title('Top 10 Positive Reviews',fontsize = 18)
plt.xlabel('Number of Positive Review',fontsize = 15)
plt.ylabel('Apps',fontsize = 15)
# Out:
# Text(0, 0.5, 'Apps')

# %%
# Chart - 6.2 visualization code

# Showing the Visual using Bar chart
Highest_negative_review.plot.barh(figsize = (10,10),fontsize = 12, color =['palegreen','limegreen' ], edgecolor = 'black')

# Using for function to show the datalabels in Visual
for index,value in enumerate(Highest_negative_review_['Negative']):
    plt.text(value, index,str(value),fontsize = 12,ha = 'right', Bbox = dict(facecolor = 'forestgreen', alpha =.6))

# Giving other labels
plt.title('Top 10 Negative Reviews',fontsize = 18)
plt.xlabel('Number of Negative Review',fontsize = 15)
plt.ylabel('Apps',fontsize = 15)
# Out:
# Text(0, 0.5, 'Apps')

# %%
# Chart - 6.3 visualization code

# Showing the Visual using Bar chart
Highest_neutral_review.plot.barh(figsize = (10,10),fontsize = 12, color =['gainsboro','darkgray' ], edgecolor = 'black')

# Using for function to show the datalabels in Visual
for index,value in enumerate(Highest_neutral_review_['Neutral']):
    plt.text(value, index,str(value),fontsize = 12,ha = 'right', Bbox = dict(facecolor = 'whitesmoke', alpha =.8))

# Giving other labels    
plt.title('Top 10 Neutral Reviews',fontsize = 18)
plt.xlabel('Number of Neutral Review',fontsize = 15)
plt.ylabel('Apps',fontsize = 15)
# Out:
# Text(0, 0.5, 'Apps')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another. By leveraging the power of bar charts, we can gain valuable insights into our data and make informed decisions.
#
# I chose a horizontal bar chart, which clearly illustrates the order of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I have analyzed the reviews that expressed positive, negative, and neutral sentiments, and identified the top 10 apps with the highest reviews in each category. This analysis has enabled us to determine which apps need to be further developed and which apps should focus more on their features to increase their usability.
#
# Points that we can understand from the Analysis:
#
# In Positive Reviews: Helix jump app got the highest number of reviews that is 209
#
# In Negative Reviews: Angry Birds classic app got the highest number of reviews that is 147
#
# In Neutral Reviews: Bet now - watch shows app got the highest number of reviews that is 39

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this analysis, we can prevent negative growth; that is, the apps that have received more negative and neutral reviews should focus on further developing their apps to better meet user interests.

# %% [markdown]
# #### **Chart - 7 - Objective 7 : Analysis of top 10 Entertaining App ,with three different categories by the user**

# %%
# Chart - 7.1 visualization code

# Showing the Visual using Bar chart
df7_1.plot.barh( stacked = True, figsize =(12,12),fontsize = 12, color = ['pink'], legend = False)

# Using for function to show the datalabels in Visual
for index,value in enumerate(df7_1['Installs']):
    plt.text(value, index,str(value),fontsize = 12,ha = 'center',Bbox = dict(facecolor = 'deeppink', alpha =.6))

# Giving other labels    
plt.title('Highest Number of Installs a App got in Category - Entertainment',fontsize = 18)
plt.xlabel('Number of Installs',fontsize = 15)
plt.ylabel('Apps',fontsize = 15)
# Out:
# Text(0, 0.5, 'Apps')

# %%
# Chart - 7.2 visualization code

# Showing the Visual using Bar chart
df7_2.plot.barh(y = 'Rating', figsize =(10,10),fontsize = 12, color = ['lightsteelblue'],legend = False)

# Using for function to show the datalabels in Visual
for index,value in enumerate(df7_2['Rating']):
    plt.text(value, index,str(value),fontsize = 12,ha = 'right',Bbox = dict(facecolor = 'mediumpurple', alpha =.8))
    
plt.title('Highest Rating a App got in Category - Entertainment',fontsize = 15)
plt.xlabel('Ratings',fontsize = 15)
plt.ylabel('Apps',fontsize = 15)
# Out:
# Text(0, 0.5, 'Apps')

# %%
# Chart - 7.3 visualization code

# Showing the Visual using Bar chart
df7_3.plot.barh(y = 'Reviews', figsize =(10,10),fontsize = 12, color = ['bisque'],legend = False)

# Using for function to show the datalabels in Visual
for index,value in enumerate(df7_3['Reviews']):
    plt.text(value, index,str(value) ,fontsize = 12,ha = 'right', Bbox = dict(facecolor = 'tomato', alpha =.8))
    
plt.title('Highest Number of Review a App got in Category - Entertainment',fontsize = 18)
plt.xlabel('Number of Reviews',fontsize = 15)
plt.ylabel('Apps',fontsize = 15)
# Out:
# Text(0, 0.5, 'Apps')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another. By leveraging the power of bar charts, we can gain valuable insights into our data and make informed decisions.
#
# I chose a horizontal bar chart, which clearly illustrates the order of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart above, it is evident that the top 10 apps in the Entertainment category have the highest numbers in ratings, reviews, and installs. It is clear that the Google Play Games app has the highest number of installs at 1,000,000,000 and the highest number of reviews at 7,165,362, yet it failed to achieve a high rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From our insights, we discovered that entertainment apps have a high number of installations by users. To ensure success, we must focus on the features and usability of the apps. By optimizing these elements, we can ensure that users have a positive experience and are more likely to continue using the app.

# %% [markdown]
# #### **Chart - 8 - Objective 8:To Analyze which app size has the Highest number of installs**

# %%
# Chart - 8 visualization code
# printing the final results to compare with result
print(df8_all_)

# Showing the Visual using Treemap
plt.figure(figsize=(12,8), dpi= 80)

squarify.plot(sizes=df8_all_['Installs'], label= df8_all_.index , 
              color=["indigo","blueviolet","mediumorchid","purple","violet","black"], alpha=.8 )
plt.axis('off')
# Out:
#                       Installs
# Below 25MB          1637275118
# 25MB to 50MB        2386041915
# 50MB to 100MB       7391986220
# Above 100MB          117161000
# Varies with device  2346460162
# Apps in KB              151000
# (0.0, 100.0, 0.0, 100.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Treemap is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another.
#
# I selected a Treemap to gain a clear visual representation of the data based on its size. This intuitive approach allows for a more comprehensive understanding of the information.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart above, it is evident that the highest number of app installations is for apps sized between 50MB-100MB, with 7,391,986,220 installations. Conversely, the lowest number of installations is for apps sized in KB, with 1,51,000 installations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights provide an answer that the app size does not matter if a user is truly interested in the app. For example, the app in KB has a count of 3, yet the number of installations is 151,000. This demonstrates that the size of the app does not affect its popularity.

# %% [markdown]
# #### **Chart - 9 - Objective 9 : Analysis of apps which got the highest Number of Reviews**

# %%
# Chart - 9 visualization code

# Showing the Visual using Bar chart
df9_.plot.barh(figsize = (10,10),fontsize = 12, color = 'lightgray')
# Using for function to show the datalabels in Visual
for index,value in enumerate(df9_['Reviews']):
    plt.text(value, index, str(value),fontsize = 11,ha = 'right', Bbox = dict(facecolor = 'tomato', alpha =.8))

# Giving other labels    
plt.title('Top 10 Apps which got the Highest number of Reviews',fontsize = 15)
plt.xlabel('Number of Reviews',fontsize= 15 )
plt.ylabel('Apps',fontsize = 15)
# Out:
# Text(0, 0.5, 'Apps')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another. By leveraging the power of bar charts, we can gain valuable insights into our data and make informed decisions.
#
# I chose a horizontal bar chart, which clearly illustrates the order of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart above, we can see that the top 10 apps have the highest number of reviews split between social media (50%), gaming (30%), and antivirus (20%) applications. This data indicates that social media and gaming apps are the most popular among users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, we have a positive business insight in which users are actively engaging with categories such as social media and gaming. Therefore, developing an app in these categories would be highly beneficial and have a positive impact on users.

# %% [markdown]
# #### **Chart - 10 - Objective 10 : Analysis of Medical category, to know the user preferences**

# %%
# Chart - 10 visualization code

# Showing the Visual using Treemap
plt.figure(figsize=(12,8), dpi= 80)

squarify.plot(sizes=df10_['Installs'], label=df10_['App'],
              color=[ "dimgray","darkgray","gainsboro","silver","silver","gainsboro","gainsboro",
                       "silver","silver","gainsboro"], alpha=.8 )

plt.axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Treemap is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another.
#
# I selected a Treemap to gain a clear visual representation of the data based on its size. This intuitive approach allows for a more comprehensive understanding of the information.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can see that the apps that are installed the most are those that track periodically occurring habits. This makes the Medical category an important need for users. They need an app that tracks days and notifies them when the target day arrives, or they need a nurse-like app that tells them all the details about their health, such as blood pressure and oxygen levels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, we have insights that will make a positive business impact, such as developing an app that provides users with all the details about their particular needs. This app should be easily connectable with people, allowing them to track their family members, such as fathers, mothers, and pregnant women, directly from their phones. This way, they can arrange for the necessary assistance as soon as the app notifies them.

# %% [markdown]
# #### **Chart - 11 - Objectice 11: Analysis of Distribution of Rating**

# %%
# Chart - 11 visualization code

# Printing each value that we extracted
print(df11_1)
print(df11_2)
print(df11_3)
print(df11_4)

# Assignng the values and labels to the variables for ease of Visualing
Rating_count = [54,225,1631,6286 ]
Categories = ['1.0 to 2.0','2.0 to 3.0','3.0 to 4.0','4.0 to 5.0']

# Showing the visual using Doughnut chart
plt.pie(Rating_count ,labels= Categories ,colors=['darkgreen','forestgreen','springgreen','palegreen'],
        wedgeprops = { 'linewidth' : 1.5, 'edgecolor' : 'white' })

my_circle=plt.Circle((0,0), 0.5, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
# Out:
# Rating    54
# dtype: int64
# Rating    225
# dtype: int64
# Rating    1631
# dtype: int64
# Rating    6286
# dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Doughnut chart is an effective way to illustrate the part-to-whole relationship in a data. It is easy to explain the percentage comparison through the area covered in a circle, which is divided into different colors. Doughnut charts are frequently used when comparing different percentages. I used a Doughnut chart to compare the percentage of the dependent variable, which proved to be a useful tool.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart above, it is evident that the highest number of apps are rated between 4.0 and 5.0, while the lowest number of apps are rated between 1.0 and 2.0. This indicates a clear disparity in the ratings of apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, certainly this insight has had a positive business impact, as the majority of the apps have achieved ratings of 3.5 or higher. However, these apps should strive to further improve their features in order to increase their ratings even more. Conversely, those apps that have ratings below 3.5 should focus on developing their app, as this will be essential for achieving positive business growth.

# %% [markdown]
# #### **Chart - 12 - Objective 12: Analysis of Highest Installs as per Category**

# %%
# Chart - 12 visualization code

# Printing the Number of Installs category wise
print(df12_.sort_values(ascending = False))

# Showing the Visual using Bar chart
df12_.sort_values().plot.barh(figsize = (10,10),fontsize = 12, color = 'indianred' )

# Giving other labels
plt.title('Number of Installs - Category wise',fontsize = 18)
plt.xlabel('Number of Installs',fontsize = 15)
plt.ylabel('Apps',fontsize = 15)
# Out:
# Category
# COMMUNICATION          35042147.0
# VIDEO_PLAYERS          24091428.0
# SOCIAL                 22961790.0
# ENTERTAINMENT          20722157.0
# PHOTOGRAPHY            16545009.0
# PRODUCTIVITY           15489549.0
# GAME                   14472288.0
# TRAVEL_AND_LOCAL       13218663.0
# TOOLS                   9675661.0
# NEWS_AND_MAGAZINES      9327629.0
# BOOKS_AND_REFERENCE     7504367.0
# SHOPPING                6932420.0
# WEATHER                 4570893.0
# PERSONALIZATION         4075784.0
# HEALTH_AND_FITNESS      3972300.0
# MAPS_AND_NAVIGATION     3841846.0
# SPORTS                  3373768.0
# EDUCATION               2965983.0
# FAMILY                  2416999.0
# FOOD_AND_DRINK          1891060.0
# ART_AND_DESIGN          1786533.0
# BUSINESS                1659916.0
# LIFESTYLE               1365375.0
# FINANCE                 1319851.0
# HOUSE_AND_HOME          1313682.0
# DATING                   824129.0
# COMICS                   803235.0
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another. By leveraging the power of bar charts, we can gain valuable insights into our data and make informed decisions.
#
# I chose a horizontal bar chart, which clearly illustrates the order of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart above, it is evident that the Communication category has the highest number of installs, at 35,042,147 , while the Medical category has the lowest, at 96,692. This disparity highlights the popularity of communication apps compared to those in other categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights have a positive business impact, such as the top 10 categories having a lot of users. If we develop an app in those categories, it will give us huge growth and great success for that app. Additionally, we can prevent categories with low install numbers by developing even better apps.

# %% [markdown]
# #### **Chart - 13 - Objective 13 : Correlation Heatmap for:**
#
# **(i) Categories - Arts and design,Family,Health and fitness.**
#
# **(ii) With complete data of Installs,Rating,Reviews,Size.**

# %%
# Chart - 13 visualization code

# Showing the visual using Correlation Heatmap

# Selecting randomly 3 Categories in the App and giving the Correlation Heatmap for that Category with Rating , Reviews, Size, Installs

# Also making an Correlation Heatmap for the Overall data in Rating, Reviews, Size, Installs

# %%
# Chart - 13.1 visualization
# Separating the Category - Arts and Design
df13__1 = df13_1.loc[df13_1.Category == 'ART_AND_DESIGN']

corr_df13__1 = df13__1.corr().round(2)

plt.figure(figsize =(8,8))
plot = sea.heatmap(corr_df13__1, annot = True)
plot.set_title('ART_AND_DESIGN -CORRELATION HEATMAP')
# Out:
# Text(0.5, 1.0, 'ART_AND_DESIGN -CORRELATION HEATMAP')

# %%
# Chart - 13.2 visualization
# Separating the Category - Family
df13__2 = df13_1.loc[df13_1.Category == 'FAMILY']

corr_df13__2 = df13__2.corr().round(2)

plt.figure(figsize =(8,8))
plot = sea.heatmap(corr_df13__2, annot = True)
plot.set_title('FAMILY - CORRELATION HEATMAP')
# Out:
# Text(0.5, 1.0, 'FAMILY - CORRELATION HEATMAP')

# %%
# Chart - 13.3 visualization
# Separating the Category - Health and Fitness
df13__3 = df13_1.loc[df13_1.Category == 'HEALTH_AND_FITNESS']

corr_df13__3 = df13__3.corr().round(2)

plt.figure(figsize =(8,8))
plot = sea.heatmap(corr_df13__3, annot = True)
plot.set_title('HEALTH_AND_FITNESS - CORRELATION HEATMAP')
# Out:
# Text(0.5, 1.0, 'HEALTH_AND_FITNESS - CORRELATION HEATMAP')

# %%
# Chart - 13.4 visualization
# Heatmap with Overall data

corr_mat_df13_ = df13_.corr().round(2)

plt.figure(figsize =(8,8))
plot = sea.heatmap(corr_mat_df13_, annot = True)
plot.set_title('Overall Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Overall Correlation Heatmap')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation Heatmap are a type of plot that visualizes the strength of relationships between numerical variables. These plots are used to identify which variables are related to each other and the magnitude of this relationship. By utilizing correlation heatmaps, one can gain a better understanding of the underlying relationships between variables and how they interact with one another. This can be a powerful tool for data analysis, allowing for more informed decisions to be made.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The four charts above demonstrate a consistent correlation between Reviews and Installs, while Size has a negative correlation with all other relations except rating. The overall Correlation heatmap reveals that the correlation between Installs and Reviews is 0.5, indicating a moderate relationship. However, the Categories Family and Arts-Design have a correlation between Reviews and Installs of 0.71 and 0.68 respectively, indicating a stronger correlation.
#
# The insights from the chart illustrate that the correlation of Rating is very low with every other factor. Therefore, the development team must work even harder to build strong ratings. Doing so will have a significant positive impact on the business.

# %% [markdown]
# #### **Chart - 14 - Objective 14: Pairplot**
#
# **Pairplot with columns - Installs,Rating,Reviews,Size in the aspect of "Type"**

# %%
# Pairplot visualization code
# With the columns Rating,Reviews,Size,Installs we are making a pairplot in consideration of the Type of Apps

sea.pairplot(df14_1, hue = 'Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Seaborn Pairplot facilitates plotting pairwise relationships between variables within a dataset, providing a visually appealing way to summarize a large amount of data in a single figure. This allows us to gain a better understanding of the data and identify any correlations or patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart above, we can gain a detailed understanding of the relationship between each column. We have plotted this pair plot with the Rating, Reviews, Size, Installs, and the type of apps (Free and Paid). As we can see in the Correlation Heatmap, there is a low and high correlation between Reviews and Installs, depending on the type of app.
#
# Free apps have a higher rating than paid apps, while paid apps have more reviews than free apps.
#
# In terms of size, free apps tend to be larger than their paid counterparts.
#
# Finally, both free and paid apps have similar install categories (1M+,10000+).

# %% [markdown]
# #### **Chart - 15 - Objective 15 : Analysis of category - Dating by sorting the top 10 Highest number of Installs and within that analysing the top 10 apps with Highest Rating**

# %%
# Pair Plot visualization code

# Showing the visual using Bar chart
df15_3.plot.barh(y = 'Rating',stacked = True ,figsize = (10,10),fontsize = 12 , color = ['lavender','lightsteelblue'])

# Using for function to show the datalabels in Visual
for index,value in enumerate(df15_3['Rating']):
    plt.text(value, index, str(value),fontsize = 11,ha = 'right', Bbox = dict(facecolor = 'royalblue', alpha =.6))

# Giving other labels
plt.title('Top 10 Apps by Installs and Rating',fontsize = 18)
plt.xlabel('Rating of the App',fontsize = 15)
plt.ylabel('Apps',fontsize = 15)
# Out:
# Text(0, 0.5, 'Apps')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is an effective way to visualize data distributions. It allows us to quickly identify which data is most prominent and how they compare to one another. By leveraging the power of bar charts, we can gain valuable insights into our data and make informed decisions.
#
# I chose a horizontal bar chart, which clearly illustrates the order of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The data from the Dating Category has been first ordered by the top 10 apps with the highest number of installs, and then sorted according to their ratings. YouLove Premium Dating, a dating app, has the highest number of installs and the highest rating, making it a favorite among users. Galaxy also has a high number of installs, but failed to achieve a high rating. Joyride, on the other hand, has fewer installs than Galaxy, but managed to get a higher rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We have a positive business impact because we have a fact that the number of installs does not matter to the user's satisfaction. Therefore, we should study the expectations of the user to develop an even more user-preferable app that will attract many users and also result in high positive growth.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# *   Always adhere to the most optimal design and features for your app in comparison to its competitors. Doing so will ensure that your app stands out from the crowd and is the most successful.
#
# *   Understand the specific expectations of users in the category you are developing and optimize the app accordingly to meet their needs. By doing so, you can ensure that your app is providing the best possible experience for your users.
#
# *   Always ensure that you keep your app up-to-date with the latest trends, so that users can benefit from them.
#
# *   Respond to each user promptly when their query is reasonable.
#
# *  Ensure that you incorporate the users' suggestions into the app updates. Doing so will ensure that the app remains up-to-date and relevant to the needs of its users.
#
# *  Always ensure that your app is user-friendly and easy to use. Make sure that the user experience is intuitive and straightforward, so that users can quickly and easily access the features they need. This will help to ensure that your app is successful and widely used.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# As we can see, there are various useful insights in the complete project that will help the business achieve positive growth. It is essential to ensure that all of these insights are used properly and effectively while developing the app.
#
# Utilize these insights to ensure the success of your business.
#
# **All the best!**
#
# **Thank you.**

# %% [markdown]
# ### ***Hurrah! I have successfully completed my EDA Capstone Project !!!***
